# %%
# magics: ensures that any changes to the modules loaded below will be re-loaded automatically
# %load_ext autoreload
# %autoreload 2

# load general packages
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# load modules related to this exercise
import tools 
import utility
from BufferStock_labor import model_bufferstock

# %%
#Load baseline settings
model = model_bufferstock()

# %%
# model.life_cycle_setup()

#Solve and simulate
model.create_grids()
model.solve()
model.simulate()

par = model.par
sol = model.sol
sim = model.sim
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# /var/folders/38/4k8gxvgx5xl9x753jsnhn1_r0000gn/T/ipykernel_46527/3567629042.py in <module>
#       3 #Solve and simulate
#       4 model.create_grids()
# ----> 5 model.solve()
#       6 model.simulate()
#       7
#
# ~/Documents/KU/10.semester/Dynamic Programming/Dynamic-Programming-Project/Bertel_Buffer/BufferStock_labor.py in solve(self)
#     179         for t in range(par.T-2,-1,-1):
#     180             # Solve model with EGM
# --> 181             egm.EGM(sol,t,par)
#     182
#     183             # add zero consumption
#
# ~/Documents/KU/10.semester/Dynamic Programming/Dynamic-Programming-Project/Bertel_Buffer/egm.py in EGM(sol, t, par)
#       6
#       7 def EGM(sol,t,par):
# ----> 8     sol = EGM_loop(sol,t,par)
#       9     # sol = EGM_vec(sol,t,par)
#      10     return sol
#
# ...

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(1,1,1)
ax.plot(sol.m[:,:],sol.c[:,:])
ax.set_xlabel(f"$m_t$")
ax.set_ylabel(f"$c(m_t)$")
ax.set_xlim([np.min(par.a_min), 10])
ax.set_ylim([0,10])
ax.set_title(f'Consumption function')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(1,1,1)
ax.plot(utility.marg_util(sol.c[:,:],par), sol.m[:,:])
ax.set_xlabel(f"$m_t$")
ax.set_ylabel(f"$c(m_t)$")
ax.set_xlim([np.min(par.a_min), 10])
ax.set_ylim([0,10])
ax.set_title(f'Consumption function')
plt.legend()
plt.show()
# Out:
# /Users/nicolaibernsen/Documents/KU/10.semester/Dynamic Programming/Dynamic-Programming-Project/Bertel_Buffer/utility.py:24: RuntimeWarning: divide by zero encountered in power
#   def marg_util(c,par):
# No handles with labels found to put in legend.
